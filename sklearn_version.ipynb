# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('data.csv')
x = df[['bmi']]
y = df['target']

# %%
# creat the model
model = LinearRegression()
model.fit(x,y)

# print the model parameters
print(f"Learned weight (w): {model.coef_[0]:.4f}")
print(f"Learned bias (b): {model.intercept_:.4f}")
# Out:
# Learned weight (w): 949.4353
# Learned bias (b): 152.1335

# %%
# plot the comparison of real data and the prediction
y_pred = model.predict(x)
plt.scatter(x, y, alpha=0.5, label = "True Data")
plt.plot(x, y_pred, color = 'red', linewidth = 2, label = "Fitted Line")
plt.xlabel("bmi")
plt.ylabel("target")
plt.title
# Out:
# <function matplotlib.pyplot.title(label: 'str', fontdict: 'dict[str, Any] | None' = None, loc: "Literal['left', 'center', 'right'] | None" = None, pad: 'float | None' = None, *, y: 'float | None' = None, **kwargs) -> 'Text'>

# %%
# evaluation metrics
mse = mean_squared_error(y,y_pred)
r2 = r2_score(y, y_pred)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"R2 score: {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 3890.4566
# R2 score: 0.3439
